# %% [markdown]
# # Various Statistic Examples / Lessons

# %%
import numpy as np
import seaborn as sns
sns.set(rc={'figure.figsize':(10,8)})

import matplotlib.pyplot as plt

# %%
# Create normal distributed samples
x = np.random.normal(1.78, 0.1, 1000)
y = np.random.normal(1.66, 0.1, 1000)


# calculate Arithmetic mean of sample
n = x.shape[0]
xbar = 1 / n * np.sum(x) 
ybar = 1 / n * np.sum(y) 
print("xbar: ", xbar)
print("ybar: ", xbar)


# calculate Variance of sample
xvar = 1 / (n - 1) * np.sum((x-xbar)**2) # Hurrraaayyy for Broadcasting!
xdev = np.sqrt(xvar)
print("xvar: ", xvar)
print("xdev: ", xdev)
# Out:
# xbar:  1.7828989208878325
# ybar:  1.7828989208878325
# xvar:  0.010560939300981531
# xdev:  0.10276643080783497

# %%
#ax = plt.hist(y)
ax2 = sns.distplot(x)
